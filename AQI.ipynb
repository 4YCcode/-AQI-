# %%
import requests

# %%
url='https://data.epa.gov.tw/api/v2/aqx_p_432?api_key=e8dd42e6-9b8b-43f8-991e-b3dee723a52d&limit=1000&sort=ImportDate%20desc&format=JSON'
data=requests.get(url)
data_json = data.json()              
for i in data_json['records']: 
    print(i["county"],"-",i['sitename']," ","AQI:",i['aqi']," 空氣品質:",i['status'])
# Out:
# 基隆市 - 基隆   AQI: 43  空氣品質: 良好
# 新北市 - 汐止   AQI: 48  空氣品質: 良好
# 新北市 - 萬里   AQI: 45  空氣品質: 良好
# 新北市 - 新店   AQI: 38  空氣品質: 良好
# 新北市 - 土城   AQI: 42  空氣品質: 良好
# 新北市 - 板橋   AQI: 48  空氣品質: 良好
# 新北市 - 新莊   AQI: 49  空氣品質: 良好
# 新北市 - 菜寮   AQI: 42  空氣品質: 良好
# 新北市 - 林口   AQI: 32  空氣品質: 良好
# 新北市 - 淡水   AQI: 34  空氣品質: 良好
# 臺北市 - 士林   AQI: 41  空氣品質: 良好
# 臺北市 - 中山   AQI: 45  空氣品質: 良好
# 臺北市 - 萬華   AQI: 41  空氣品質: 良好
# 臺北市 - 古亭   AQI: 53  空氣品質: 普通
# 臺北市 - 松山   AQI: 45  空氣品質: 良好
# 臺北市 - 大同   AQI: 60  空氣品質: 普通
# 桃園市 - 桃園   AQI: 47  空氣品質: 良好
# 桃園市 - 大園   AQI: 52  空氣品質: 普通
# 桃園市 - 觀音   AQI: 54  空氣品質: 普通
# 桃園市 - 平鎮   AQI: 36  空氣品質: 良好
# 桃園市 - 龍潭   AQI: 47  空氣品質: 良好
# 新竹縣 - 湖口   AQI: 52  空氣品質: 普通
# 新竹縣 - 竹東   AQI: 43  空氣品質: 良好
# 新竹市 - 新竹   AQI: 48  空氣品質: 良好
# 苗栗縣 - 頭份   AQI: 47  空氣品質: 良好
# 苗栗縣 - 苗栗   AQI: 53  空氣品質: 普通
# 苗栗縣 - 三義   AQI: 60  空氣品質: 普通
# 臺中市 - 豐原   AQI: 58  空氣品質: 普通
# 臺中市 - 沙鹿   AQI: 67  空氣品質: 普通
# 臺中市 - 大里   AQI: 65  空氣品質: 普通
# 臺中市 - 忠明   AQI: 67  空氣品質: 普通
# 臺中市 - 西屯   AQI: 76  空氣品質: 普通
# ...

# %%
import csv
import os

# %%
os.chdir('D:\Python-training\project\空氣品質指標(AQI)') #更改路徑(原路徑在C:\Users\amand)
csvfile = open('AQI_ipy.csv', 'w')    # 建立空白並可寫入的 CSV 檔案
csv_write = csv.writer(csvfile)

output = [['縣市','地區','AQI','空氣品質']]    # 設定 output 變數為二維串列，第一筆資料為開頭
for i in data_json['records']:
    # 依序將取得的資料加入 output 中
    output.append([i['county'],i['sitename'],i['aqi'],i['status']])
print(output)
csv_write.writerows(output)   # 多行寫入 CSV
# Out:
# [['縣市', '地區', 'AQI', '空氣品質'], ['基隆市', '基隆', '43', '良好'], ['新北市', '汐止', '48', '良好'], ['新北市', '萬里', '45', '良好'], ['新北市', '新店', '38', '良好'], ['新北市', '土城', '42', '良好'], ['新北市', '板橋', '48', '良好'], ['新北市', '新莊', '49', '良好'], ['新北市', '菜寮', '42', '良好'], ['新北市', '林口', '32', '良好'], ['新北市', '淡水', '34', '良好'], ['臺北市', '士林', '41', '良好'], ['臺北市', '中山', '45', '良好'], ['臺北市', '萬華', '41', '良好'], ['臺北市', '古亭', '53', '普通'], ['臺北市', '松山', '45', '良好'], ['臺北市', '大同', '60', '普通'], ['桃園市', '桃園', '47', '良好'], ['桃園市', '大園', '52', '普通'], ['桃園市', '觀音', '54', '普通'], ['桃園市', '平鎮', '36', '良好'], ['桃園市', '龍潭', '47', '良好'], ['新竹縣', '湖口', '52', '普通'], ['新竹縣', '竹東', '43', '良好'], ['新竹市', '新竹', '48', '良好'], ['苗栗縣', '頭份', '47', '良好'], ['苗栗縣', '苗栗', '53', '普通'], ['苗栗縣', '三義', '60', '普通'], ['臺中市', '豐原', '58', '普通'], ['臺中市', '沙鹿', '67', '普通'], ['臺中市', '大里', '65', '普通'], ['臺中市', '忠明', '67', '普通'], ['臺中市', '西屯', '76', '普通'], ['彰化縣', '彰化', '84', '普通'], ['彰化縣', '線西', '78', '普通'], ['彰化縣', '二林', '86', '普通'], ['南投縣', '南投', '62', '普通
# ...
